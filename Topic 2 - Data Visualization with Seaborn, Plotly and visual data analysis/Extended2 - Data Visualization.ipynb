# %%
# отключим предупреждения Anaconda
import warnings
warnings.simplefilter('ignore')

# будем отображать графики прямо в jupyter'e
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
#графики в svg выглядят более четкими
# %config InlineBackend.figure_format = 'svg' 

#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 8, 5
import pandas as pd

# %%
df = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
# Name               16717 non-null object
# Platform           16719 non-null object
# Year_of_Release    16450 non-null float64
# Genre              16717 non-null object
# Publisher          16665 non-null object
# NA_Sales           16719 non-null float64
# EU_Sales           16719 non-null float64
# JP_Sales           16719 non-null float64
# Other_Sales        16719 non-null float64
# Global_Sales       16719 non-null float64
# Critic_Score       8137 non-null float64
# Critic_Count       8137 non-null float64
# User_Score         10015 non-null object
# User_Count         7590 non-null float64
# Developer          10096 non-null object
# Rating             9950 non-null object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
df = df.dropna()
print(df.shape)
# Out:
# (6825, 16)

# %%
df.head()
# Out:
#                     Name Platform  Year_of_Release     Genre Publisher  \
# 0             Wii Sports      Wii           2006.0    Sports  Nintendo
# 2         Mario Kart Wii      Wii           2008.0    Racing  Nintendo
# 3      Wii Sports Resort      Wii           2009.0    Sports  Nintendo
# 6  New Super Mario Bros.       DS           2006.0  Platform  Nintendo
# 7               Wii Play      Wii           2006.0      Misc  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 6     11.28      9.14      6.50         2.88         29.80          89.0
# 7     13.96      9.18      2.93         2.84         28.92          58.0
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
useful_cols = ['Name', 'Platform', 'Year_of_Release', 'Genre', 
               'Global_Sales', 'Critic_Score', 'Critic_Count',
               'User_Score', 'User_Count', 'Rating'
              ]
df[useful_cols].head()
# Out:
#                     Name Platform  Year_of_Release     Genre  Global_Sales  \
# 0             Wii Sports      Wii           2006.0    Sports         82.53
# 2         Mario Kart Wii      Wii           2008.0    Racing         35.52
# 3      Wii Sports Resort      Wii           2009.0    Sports         32.77
# 6  New Super Mario Bros.       DS           2006.0  Platform         29.80
# 7               Wii Play      Wii           2006.0      Misc         28.92
#
#    Critic_Score  Critic_Count User_Score  User_Count Rating
# 0          76.0          51.0          8       322.0      E
# 2          82.0          73.0        8.3       709.0      E
# 3          80.0          73.0          8       192.0      E
# 6          89.0          65.0        8.5       431.0      E
# 7          58.0          41.0        6.6       129.0      E

# %%
sales_df = df[[x for x in df.columns if 'Sales' in x] + ['Year_of_Release']]
sales_df.groupby('Year_of_Release').sum().plot()

# %%
sales_df.head(1)
# Out:
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Year_of_Release
# 0     41.36     28.96      3.77         8.45         82.53           2006.0

# %%
sales_df = df[[x for x in df.columns if 'Sales' in x] + ['Genre']]

# %%
sales_df.groupby('Genre').sum().plot(kind='bar', rot=45)

# %%
sales_df.head(1)
# Out:
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales   Genre
# 0     41.36     28.96      3.77         8.45         82.53  Sports

# %%
sales_df = df[[x for x in df.columns if 'Sales' in x] + ['Rating']]
sales_df.groupby('Rating').sum().plot(kind='bar', rot=45)

# %%
cols = ['Global_Sales', 'Year_of_Release']
sns_plot = sns.pairplot(df[cols])

# %%
sns.distplot(df['Critic_Score'])
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df['User_Score'] = df.User_Score.astype('float64')

# %%
sns.jointplot(df.Critic_Score, df.User_Score)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\User\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df['Year_of_Release'] = df.Year_of_Release.astype('int64')
df['User_Count'] = df.User_Count.astype('int64')
df['Critic_Count'] = df.Critic_Count.astype('int64')

# %%
top_platforms = df.Platform.value_counts().sort_values(ascending = False).head(5).index.values
sns.boxplot(y="Platform", x="Critic_Score", data=df[df.Platform.isin(top_platforms)], orient="h")

# %%
df.head(5)
# Out:
#                     Name Platform  Year_of_Release     Genre Publisher  \
# 0             Wii Sports      Wii             2006    Sports  Nintendo
# 2         Mario Kart Wii      Wii             2008    Racing  Nintendo
# 3      Wii Sports Resort      Wii             2009    Sports  Nintendo
# 6  New Super Mario Bros.       DS             2006  Platform  Nintendo
# 7               Wii Play      Wii             2006      Misc  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 6     11.28      9.14      6.50         2.88         29.80          89.0
# 7     13.96      9.18      2.93         2.84         28.92          58.0
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %%
platform_publisher_sales = df.pivot_table(
                            index='Platform',
                            columns='Genre',
                            values='Global_Sales',
                            aggfunc=sum).fillna(0).applymap(float)

# %%
platform_publisher_sales.head()
# Out:
# Genre     Action  Adventure  Fighting   Misc  Platform  Puzzle  Racing  \
# Platform
# 3DS        30.81       2.00      2.63   4.48     27.61    2.63   13.89
# DC          0.00       1.33      0.56   0.00      0.12    0.00    0.20
# DS         42.43       8.83      3.37  68.82     55.02   50.50   29.93
# GBA        23.21       4.54      3.28   8.59     40.36    5.47   12.60
# GC         29.99       4.56     15.81  12.72     24.67    3.31   11.09
#
# Genre     Role-Playing  Shooter  Simulation  Sports  Strategy
# Platform
# 3DS              18.94     1.02       16.08    2.20      0.94
# DC                0.68     0.05        0.52    1.09      0.00
# DS               60.31     6.40       42.71    6.01      8.00
# GBA              21.00     1.40        2.03    5.93      3.34
# GC               12.48    13.04        8.39   19.91      3.45

# %%
heatplot = sns.heatmap(platform_publisher_sales, annot=True, fmt=".1f", linewidths=.5)

# %%
years_df = df.groupby('Year_of_Release')[['Global_Sales']].sum().join(
    df.groupby('Year_of_Release')[['Name']].count())

# %%
years_df.columns = ['Global_Sales', 'Number_of_Games']

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly
import plotly.graph_objs as go

init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
trace0 = go.Scatter(
    x=years_df.index,
    y=years_df.Global_Sales,
    name='Global Sales'
)

# %%
trace1 = go.Scatter(
    x=years_df.index,
    y=years_df.Number_of_Games,
    name='Number of games released'
)

# %%
data = [trace0, trace1]
layout = {'title': 'Statistics of video games'}

# %%
fig = go.Figure(data=data, layout=layout)
iplot(fig, show_link=False)
# Out:
# <div id="4a8a5ea6-c651-4160-aad7-b3068a86bb0b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4a8a5ea6-c651-4160-aad7-b3068a86bb0b", [{"name": "Global Sales", "x": [1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2020.0], "y": [11.379999999999999, 35.77000000000001, 28.859999999999996, 16.790000000000003, 50.360000000000014, 53.940000000000005, 37.07, 21.739999999999995, 47.22, 73.45, 49.38999999999999, 32.230000000000004, 76.16999999999997, 48.399999999999984, 79.18000000000002, 88.10999999999991, 199.14999999999995, 200.98000000000013, 256.4499
# ...

# %%
plotly.offline.plot(fig, filename='years_stats.html', show_link=False)
# Out:
# 'file://C:\\Users\\User\\PycharmProjects\\years_stats.html'

# %%
platforms_df = df.groupby('Platform')[['Global_Sales']].sum().join(
    df.groupby('Platform')[['Name']].count()
)

# %%
platforms_df.columns = ['Global_Sales', 'Number_of_Games']

# %%
platforms_df.sort_values('Global_Sales', ascending=False, inplace=True)

# %%
trace0 = go.Bar(
        x=platforms_df.index,
        y=platforms_df.Global_Sales,
        name='Global Sales')

trace1 = go.Bar(
        x=platforms_df.index,
        y=platforms_df.Number_of_Games,
        name='Number of games released')

data = [trace0, trace1]
layout = {'title': 'Share of platforms', 'xaxis': {'title': 'platform'}}

# %%
fig1 = go.Figure(data=data, layout=layout)
iplot(fig1, show_link=False)
# Out:
# <div id="49a67caf-56af-4f33-8689-7aa62d896c26" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("49a67caf-56af-4f33-8689-7aa62d896c26", [{"name": "Global Sales", "x": ["PS2", "X360", "PS3", "Wii", "DS", "PS", "GBA", "PS4", "PSP", "PC", "3DS", "XB", "GB", "NES", "N64", "SNES", "GC", "XOne", "2600", "WiiU", "PSV", "SAT", "GEN", "DC", "SCD", "NG", "WS", "TG16", "3DO", "GG", "PCFX"], "y": [1255.6399999999871, 971.6299999999992, 939.4299999999982, 908.129999999998, 807.0999999999868, 730.679999999997, 318.499999999998, 314.22999999999905, 294.2999999999953, 260.29999999999643, 259.0899999999991, 258.25999999999834, 255.44999999999987, 251.06999999999988, 218.87999999999985, 200.05000000000024, 199.3600000000007, 159.44000000000003, 97.08000000000003, 82.16000000000003, 54.12000000000018, 33.59000000000002
# ...

# %%
plotly.offline.plot(fig1, filename='platform_sales_stats.html', show_link=False)
# Out:
# 'file://C:\\Users\\User\\PycharmProjects\\platform_sales_stats.html'

# %%
data = []

# %%
for genre in df.Genre.unique():
    data.append(
        go.Box(y=df[df.Genre==genre].Critic_Score, name=genre))

# %%
iplot(data, show_link = False)
# Out:
# <div id="4c46d608-c562-46d8-b9df-d475ee87d45e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4c46d608-c562-46d8-b9df-d475ee87d45e", [{"name": "Sports", "y": [76.0, 80.0, 80.0, 80.0, 82.0, null, 85.0, null, null, 86.0, 73.0, 82.0, 94.0, null, 89.0, 92.0, 88.0, 98.0, null, 91.0, 84.0, 97.0, 86.0, null, 84.0, 80.0, null, 95.0, null, null, null, 81.0, 90.0, 87.0, 91.0, 76.0, null, 81.0, 94.0, 82.0, 91.0, 88.0, 84.0, null, 88.0, 84.0, 83.0, null, 83.0, 94.0, null, null, 87.0, 88.0, 93.0, null, 93.0, 67.0, 85.0, 81.0, 85.0, null, null, 89.0, null, 78.0, 84.0, 84.0, 80.0, 90.0, 90.0, 90.0, 84.0, 79.0, 87.0, 78.0, 83.0, 83.0, 87.0, 50.0, null, 90.0, 83.0, 84.0, null, 77.0, 83.0, 85.0, 83.0, 42.0, 85.0, 86.0, 66.0, null, null, null, 78.0, 82.0, null, 79.0, 80.0, null, 81.0, 82.0, null, null, 62.0, null, 9
# ...

# %%
plotly.offline.plot(data, filename='genre_boxplots.html', show_link=False)
# Out:
# 'file://C:\\Users\\User\\PycharmProjects\\genre_boxplots.html'

# %%
strategy_df = df[df['Genre'] == 'Strategy']

# %%
strategy_sales_by_year = strategy_df.groupby('Year_of_Release')[['Global_Sales']].sum().join(df.groupby('Year_of_Release')[['Name']].count())

# %%
strategy_sales_by_year.columns = ['Global_Sales', 'Number_of_Games']

# создаем линию для числа проданных копий
trace0 = go.Scatter(
    x=strategy_sales_by_year.index,
    y=strategy_sales_by_year.Global_Sales,
    name='Global Sales'
)

# создаем линию для числа вышедших игр 
trace1 = go.Scatter(
    x=strategy_sales_by_year.index,
    y=strategy_sales_by_year.Number_of_Games,
    name='Number of games released'
)

# определяем массив данных и задаем title графика в layout
data = [trace0, trace1]
layout = {'title': 'Statistics of video games'}

# cоздаем объект Figure и визуализируем его
fig = go.Figure(data=data, layout=layout)
iplot(fig, show_link=False)
# Out:
# <div id="aa2c35b9-c9a5-4553-8dba-12a1ca0cf715" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("aa2c35b9-c9a5-4553-8dba-12a1ca0cf715", [{"name": "Global Sales", "x": [1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0], "y": [0.94, 0.37, 0.81, 3.5600000000000005, 6.510000000000001, 5.610000000000001, 7.710000000000002, 13.46, 18.450000000000006, 8.520000000000001, 7.55, 5.559999999999998, 7.990000000000002, 7.16, 5.31, 4.219999999999994, 9.25999999999999, 11.549999999999995, 12.359999999999989, 13.769999999999989, 8.839999999999995, 3.269999999999999, 6.09, 0.9900000000000002, 1.8400000000000003, 1.1500000000000001], "type": "scatter", "uid": "43
# ...

# %%
df = df.dropna()
df.head(10)
# Out:
#                          Name Platform  Year_of_Release     Genre  \
# 0                  Wii Sports      Wii           2006.0    Sports
# 2              Mario Kart Wii      Wii           2008.0    Racing
# 3           Wii Sports Resort      Wii           2009.0    Sports
# 6       New Super Mario Bros.       DS           2006.0  Platform
# 7                    Wii Play      Wii           2006.0      Misc
# 8   New Super Mario Bros. Wii      Wii           2009.0  Platform
# 11              Mario Kart DS       DS           2005.0    Racing
# 13                    Wii Fit      Wii           2007.0    Sports
# 14         Kinect Adventures!     X360           2010.0      Misc
# 15               Wii Fit Plus      Wii           2009.0    Sports
#
#                  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                 Nintendo     41.36     28.96      3.77         8.45
# 2                 Nintendo     15.68     12.76      3.79         3.29
# ...

# %%
columns_to_show = ['Global_Sales', 'Critic_Score']
df.groupby('Platform')[columns_to_show].min()
# Out:
#           Global_Sales  Critic_Score
# Platform
# 3DS               0.01          26.0
# DC                0.05          80.0
# DS                0.01          19.0
# GBA               0.01          24.0
# GC                0.01          23.0
# PC                0.01          33.0
# PS                0.02          26.0
# PS2               0.01          24.0
# PS3               0.01          13.0
# PS4               0.01          19.0
# PSP               0.01          28.0
# PSV               0.01          33.0
# Wii               0.01          19.0
# WiiU              0.01          24.0
# X360              0.01          19.0
# XB                0.01          19.0
# XOne              0.01          20.0
