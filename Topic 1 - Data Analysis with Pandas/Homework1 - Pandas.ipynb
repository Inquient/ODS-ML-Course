# %%
import pandas as pd

# %%
data = pd.read_csv('https://raw.githubusercontent.com/Yorko/mlcourse.ai/master/data/adult.data.csv')
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
data['sex'].value_counts()
# Out:
# Male      21790
# Female    10771
# Name: sex, dtype: int64

# %%
data[data['sex'] == 'Female']['age'].mean()
# Out:
# 36.85823043357163

# %%
data[data['native-country'] == 'Germany']
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 122     30           Private   77143     Bachelors             13
# 280     22           Private   34918     Bachelors             13
# 767     22           Private  151790  Some-college             10
# 1009    26           Private  109186  Some-college             10
# 1142    59       Federal-gov  212448       HS-grad              9
# 1346    61      Self-emp-inc  134768     Bachelors             13
# 1425    46           Private  134727          11th              7
# 1973    30           Private  111415       HS-grad              9
# 2233    35           Private  178322     Assoc-voc             11
# 2586    26                 ?  152046          11th              7
# 2788    27         State-gov  194773       Masters             14
# 2899    22           Private   24896       HS-grad              9
# 3159    58           Private  235624     Assoc-voc             11
# ...

# %%
data['native-country'].value_counts(normalize=True)
# Out:
# United-States                 0.895857
# Mexico                        0.019748
# ?                             0.017905
# Philippines                   0.006081
# Germany                       0.004207
# Canada                        0.003716
# Puerto-Rico                   0.003501
# El-Salvador                   0.003255
# India                         0.003071
# Cuba                          0.002918
# England                       0.002764
# Jamaica                       0.002488
# South                         0.002457
# China                         0.002303
# Italy                         0.002242
# Dominican-Republic            0.002150
# Vietnam                       0.002058
# Guatemala                     0.001966
# Japan                         0.001904
# Poland                        0.001843
# Columbia                      0.001812
# Taiwan                        0.001566
# Haiti                         0.001351
# Iran                          0.001321
# ...

# %%
data[data['salary'] == '>50K']['age'].describe()
# Out:
# count    7841.000000
# mean       44.249841
# std        10.519028
# min        19.000000
# 25%        36.000000
# 50%        44.000000
# 75%        51.000000
# max        90.000000
# Name: age, dtype: float64

# %%
data[data['salary'] == '<=50K']['age'].describe()
# Out:
# count    24720.000000
# mean        36.783738
# std         14.020088
# min         17.000000
# 25%         25.000000
# 50%         34.000000
# 75%         46.000000
# max         90.000000
# Name: age, dtype: float64

# %%
data[data['education'] == 'Bachelors']['salary'].value_counts()
# Out:
# <=50K    3134
# >50K     2221
# Name: salary, dtype: int64

# %%
data[(data['education'] == 'Bachelors') | 
     (data['education'] == 'Masters') | 
     (data['education'] == 'Doctorate') | 
     (data['education'] == 'Prof-school') | 
     (data['education'] == 'Assoc-acdm') | 
     (data['education'] == 'Assoc-voc')]['salary'].value_counts()
# Out:
# <=50K    5981
# >50K     4535
# Name: salary, dtype: int64

# %%
data[data['salary'] == '>50K']['education'].value_counts()
# Out:
# Bachelors       2221
# HS-grad         1675
# Some-college    1387
# Masters          959
# Prof-school      423
# Assoc-voc        361
# Doctorate        306
# Assoc-acdm       265
# 10th              62
# 11th              60
# 7th-8th           40
# 12th              33
# 9th               27
# 5th-6th           16
# 1st-4th            6
# Name: education, dtype: int64

# %%
data.head(10)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
# 5   37           Private  284582    Masters             14
# 6   49           Private  160187        9th              5
# 7   52  Self-emp-not-inc  209642    HS-grad              9
# 8   31           Private   45781    Masters             14
# 9   42           Private  159449  Bachelors             13
#
#           marital-status         occupation   relationship   race     sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# 1     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2               Divorced  Handlers-cleaners  Not-in-family  White    Male
# ...

# %%
data[data['race'] == 'Amer-Indian-Eskimo']['age'].max()
# Out:
# 82

# %%
data[(data['marital-status'] == 'Married-civ-spouse') |
     (data['marital-status'] == 'Married-spouse-absent') |
     (data['marital-status'] == 'Married-AF-spouse')]
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 14      40           Private  121772     Assoc-voc             11
# 15      34           Private  245487       7th-8th              4
# 18      38           Private   28887          11th              7
# 20      40           Private  193524     Doctorate             16
# ...

# %%
data[(data['marital-status'] == 'Married-civ-spouse') |
     (data['marital-status'] == 'Married-spouse-absent') |
     (data['marital-status'] == 'Married-AF-spouse')]['salary'].value_counts()
# Out:
# <=50K    8681
# >50K     6736
# Name: salary, dtype: int64

# %%
data[(data['marital-status'] != 'Married-civ-spouse') &
     (data['marital-status'] != 'Married-spouse-absent') &
     (data['marital-status'] != 'Married-AF-spouse')]['salary'].value_counts()
# Out:
# <=50K    16039
# >50K      1105
# Name: salary, dtype: int64

# %%
data['marital-status'].value_counts()
# Out:
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital-status, dtype: int64

# %%
data[(data['marital-status'] == 'Widowed') |
     (data['marital-status'] == 'Separated') |
     (data['marital-status'] == 'Divorced') |
     (data['marital-status'] == 'Never-married')]['salary'].value_counts()
# Out:
# <=50K    16039
# >50K      1105
# Name: salary, dtype: int64

# %%
data['hours-per-week'].max()
# Out:
# 99

# %%
data[data['hours-per-week'] == 99].shape[0]
# Out:
# 85

# %%
data[data['hours-per-week'] == 99]['salary'].value_counts(normalize=True)
# Out:
# <=50K    0.705882
# >50K     0.294118
# Name: salary, dtype: float64

# %%
data[(data['native-country'] == 'Japan') &
     (data['salary'] == '<=50K')]['hours-per-week'].mean()
# Out:
# 41.0

# %%
data[(data['native-country'] == 'Japan') &
     (data['salary'] == '>50K')]['hours-per-week'].mean()
# Out:
# 47.958333333333336
